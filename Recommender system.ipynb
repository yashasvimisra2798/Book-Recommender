# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:/Users/Yashasvi/Desktop/BX-CSV-Dump (2)/BX-Books.csv',delimiter=';',encoding='latin-1',error_bad_lines=False)
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'
# ...

# %%
data.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
data.drop(columns={'Image-URL-S','Image-URL-M','Image-URL-L'},inplace=True)

# %%
data.rename(columns={'Book-Title':'Title','Book-Author':'Author','Year-Of-Publication':'Year'},inplace=True)

# %%
data.head()
# Out:
#          ISBN                                              Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  Year                   Publisher
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company

# %%
rating=pd.read_csv('C:/Users/Yashasvi/Desktop/BX-CSV-Dump (2)/BX-Book-Ratings.csv',delimiter=';',encoding='latin-1',error_bad_lines=False)

# %%
rating.rename(columns={'Book-Rating':'Rating'},inplace=True)

# %%
rating.head()
# Out:
#    User-ID        ISBN  Rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
Users=pd.read_csv('C:/Users/Yashasvi/Desktop/BX-CSV-Dump (2)/BX-Users.csv',delimiter=';',encoding='latin-1',error_bad_lines=False)

# %%
Users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
data.shape
# Out:
# (271360, 5)

# %%
rating.shape
# Out:
# (1149780, 3)

# %%
Users.shape
# Out:
# (278858, 3)

# %%
a=rating['User-ID'].value_counts()>200;

# %%
b=a[a].index

# %%
ratings=rating[rating['User-ID'].isin(b)]

# %%
ratings.head()
# Out:
#       User-ID        ISBN  Rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
rating_for_book=ratings.merge(data,on='ISBN')

# %%
rating_for_book.rename(columns={'User-ID':'Book-ID'},inplace=True)

# %%
rating_for_book.head()
# Out:
#    Book-ID        ISBN  Rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                Title             Author  Year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    Publisher
# 0  John Wiley &amp; Sons Inc
# 1  John Wiley &amp; Sons Inc
# 2  John Wiley &amp; Sons Inc
# 3  John Wiley &amp; Sons Inc
# 4  John Wiley &amp; Sons Inc

# %%
gk=rating_for_book.groupby('Title')['Rating'].count().reset_index()

# %%
gk.head()
# Out:
#                                                Title  Rating
# 0   A Light in the Storm: The Civil War Diary of ...       2
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Beyond IBM: Leadership Marketing and Finance ...       1
# 4   Clifford Visita El Hospital (Clifford El Gran...       1

# %%
final=rating_for_book.merge(gk,on='Title')

# %%
final.head()
# Out:
#    Book-ID        ISBN  Rating_x  \
# 0   277427  002542730X        10
# 1     3363  002542730X         0
# 2    11676  002542730X         6
# 3    12538  002542730X        10
# 4    13552  002542730X         0
#
#                                                Title             Author  Year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    Publisher  Rating_y
# 0  John Wiley &amp; Sons Inc        82
# 1  John Wiley &amp; Sons Inc        82
# 2  John Wiley &amp; Sons Inc        82
# 3  John Wiley &amp; Sons Inc        82
# 4  John Wiley &amp; Sons Inc        82

# %%
final=final[final['Rating_y']>=40]

# %%
final.head()
# Out:
#    Book-ID        ISBN  Rating_x  \
# 0   277427  002542730X        10
# 1     3363  002542730X         0
# 2    11676  002542730X         6
# 3    12538  002542730X        10
# 4    13552  002542730X         0
#
#                                                Title             Author  Year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    Publisher  Rating_y
# 0  John Wiley &amp; Sons Inc        82
# 1  John Wiley &amp; Sons Inc        82
# 2  John Wiley &amp; Sons Inc        82
# 3  John Wiley &amp; Sons Inc        82
# 4  John Wiley &amp; Sons Inc        82

# %%
final.shape
# Out:
# (77224, 8)

# %%
final.drop_duplicates(['Book-ID','Title'],inplace=True)

# %%
final.shape
# Out:
# (74876, 8)

# %%
pivot=final.pivot_table(columns='Book-ID',index='Title',values='Rating_y')

# %%
pivot
# Out:
# Book-ID                                             254     2276    2766    \
# Title
# 1984                                                  76.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN    47.0     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# 2nd Chance                                             NaN   124.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# A 2nd Helping of Chicken Soup for the Soul (Chi...     NaN     NaN     NaN
# A Beautiful Mind: The Life of Mathematical Geni...     NaN     NaN     NaN
# A Bend in the Road                                   115.0     NaN   115.0
# ...

# %%
pivot.shape
# Out:
# (1091, 889)

# %%
pivot.fillna(0,inplace=True)

# %%
pivot
# Out:
# Book-ID                                             254     2276    2766    \
# Title
# 1984                                                  76.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0    47.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# 2nd Chance                                             0.0   124.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# A Bend in the Road                                   115.0     0.0   115.0
# ...

# %%
from scipy.sparse import csr_matrix
sparse=csr_matrix(pivot)

# %%
type(sparse)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors(algorithm='brute')

# %%
model.fit(sparse)
# Out:
# NearestNeighbors(algorithm='brute', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=5, p=2, radius=1.0)

# %%
distances,suggestions=model.kneighbors(pivot.iloc[393,:].values.reshape(1,-1), n_neighbors=6)

# %%
suggestions
# Out:
# array([[393, 217, 301, 522, 792,  91]], dtype=int64)

# %%
for i in range(len(suggestions)):
    print (pivot.index[suggestions[i]])
# Out:
# Index(['Insomnia', 'Desperation', 'Four Past Midnight',
#        'Nightmares &amp; Dreamscapes', 'The Dead Zone', 'Bag of Bones'],
#       dtype='object', name='Title')

# %%
np.where(pivot.index=='A Painted House')[0][0]
# Out:
# 30

# %%
def recommend_book(bookname):
    id=np.where(pivot.index==bookname)[0][0]
    distance,suggestions=model.kneighbors(pivot.iloc[id,:].values.reshape(1,-1),n_neighbors=11)
    for i in range(len(suggestions[0])):
        if i!=0:
         print(pivot.index[suggestions[0][i]])

# %%
recommend_book('A Painted House')
# Out:
# The Chamber
# The Brethren
# The Summons
# The Street Lawyer
# The King of Torts
# The Partner
# Cradle and All
# Skipping Christmas
# Insomnia
# Timeline
